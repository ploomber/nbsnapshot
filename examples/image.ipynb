# %%
import matplotlib.pyplot as plt

# %%
# force image to always have the same size
# %config InlineBackend.print_figure_kwargs = {'bbox_inches':None}
_, ax = plt.subplots(figsize=(8, 6))
ax.plot([1, 2, 3])
